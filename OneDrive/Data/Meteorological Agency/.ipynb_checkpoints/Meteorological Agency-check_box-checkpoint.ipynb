# %%
# 워드 클라우드
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image

import pandas as pd
import numpy as np
import os
import string
import sys
import re
import datetime as dt
# now = dt.datetime.now().strftime('%y%m%d_%H%M%S')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# 진행 여부 함수
def yes_or_no(question):
    while "the answer is invalid":
        reply = str(input(question+' (y/n): ')).lower().strip()
        if reply[0] == 'y':
            return True
        if reply[0] == 'n':
            return False
        else:
            print("실패: 'y' 혹은 'n' 를 입력해 주세요")

# %%
# 파일 불러오기
sheet_name = "컬럼분석"
input_path = os.path.join(os.getcwd(), "data\\")
output_path = os.path.join(os.getcwd(), "data\\out\\")
data = pd.read_excel(input_path+"기상자료개방포털 컬럼 조사.xlsx", sheet_name=sheet_name, header=0)

# # null 제거
# for i in range(len(input_test.columns)):
#     input_test[input_test.columns[i]] = input_test[input_test.columns[i]].fillna("")
# print(input_test.shape)
# input_test.head(5)

# %% [markdown]
# ### 대분류 나누기( Data1 ~ Data11)

# %%
# 컬럼리스트 만들기
col_list = data.columns.to_list()
col_list
# Out:
# ['INDEX',
#  '대분류',
#  '중분류',
#  '소분류',
#  '제공자료컬럼',
#  '예시',
#  '체크박스항목1',
#  '체크박스항목예시1',
#  '체크박스항목1Depth',
#  '체크박스항목2',
#  '체크박스항목예시2',
#  '체크박스항목2Depth',
#  '체크박스항목3',
#  '체크박스항목예시3',
#  '체크박스항목3Depth',
#  '추가',
#  '특이사항']

# %%
# 체크박스항목1,2,3 리스트
chkBox_catgr_list_1 = data['체크박스항목1'].drop_duplicates().reset_index()
chkBox_catgr_list_2 = data['체크박스항목2'].drop_duplicates().reset_index()
chkBox_catgr_list_3 = data['체크박스항목3'].drop_duplicates().reset_index()

# 체크박스 카테고리 사전
chkBox_catgr_list_1.columns = ['index', '체크박스항목']
chkBox_catgr_list_2.columns = ['index', '체크박스항목']
chkBox_catgr_list_3.columns = ['index', '체크박스항목']
chkBox_catgr_list_total = pd.concat([chkBox_catgr_list_1,chkBox_catgr_list_2,chkBox_catgr_list_3], axis=0)
chkBox_catgr_list_total
# Out:
#     index           체크박스항목
# 0       0               지점
# 1      17              NaN
# 2      54            지점-농업
# 3     100           지점-강원도
# 4     280            지점-황사
# 5     320            지점-부이
# 6     348            지점-등표
# 7     364          지점-파고부이
# 8     447          지점-레윈존데
# 9     457       지점-윈드프로파일러
# 10    470            지점-항공
# 11    872               분류
# 12    916             자료형태
# 13   1035             자료구분
# 14   1301            지점-지점
# 15   1325             자료종류
# 16   1532        수치모델-자료구분
# 17   1609            시간-시간
# 18   1633        수치모델-해양모델
# 19   1643          지점-국지해안
# 20   1648          시간-분석시간
# 21   1672          지점-온실가스
# 22   1681          지점-반응가스
# 23   1687          지점-에어로졸
# 24   1739          지점-대기복사
# 25   1748         지점-성층권오존
# 26   1751               구분
# 27   1754           지점-자외선
# 28   1758         지점-총대기침적
# 29   1788               응용
# 30   1832               규모
# 31   1861               시간
# 32   1883               종류
# 33   2048               지역
# 34   2069          지점-관측분야
# 35   2091               관측
# 0       0               관측
# 1      12              NaN
# 2     447          관측-레윈존데
# 3     457  관측-윈드프로파일러(UHC)
# 4     704         관측-GTS고층
# 5    1035     자료형태-이진(bin)
# 6    1055         자료형태-HDF
# 7    1057          자료형태-영상
# 8    1119      자료형태-NetCDF
# 9    1187        자료형태-바이너리
# 10   1225         자료형태-이미지
# 11   1301               시간
# 12   1349            예보-요소
# 13   1408            예보-특보
# 14   1514           예보-영향도
# 15   1532          시간-분석시간
# 16   1648          시간-예측시간
# 17   1672          기후-온실가스
# 18   1681          기후-반응가스
# 19   1687               기후
# 20   1748         기후-성층권오존
# 21   1754           기후-자외선
# 22   1772        기후-표준강수지수
# 23   1788               지점
# 24   2039               분류
# 0       0              NaN
# 1     100               기관
# 2    1035            지역-영역
# 3    1225     기본산출물_이미지-지역
# 4    1532          시간-예측시간

# %%
# # 각 데이터셋 분류
# # 한 엑셀 파일에 저장
# writer=pd.ExcelWriter(output_path + "test.xlsx", engine='openpyxl')
# for i,j in zip(lar_catgr,range(len(lar_catgr))):
#     globals()["data_lar_{}".format(j)] = data['대분류'] == i
#     globals()["data_lar_{}".format(j)] = data[globals()["data_lar_{}".format(j)]==True]
#     globals()["data_lar_{}".format(j)].to_excel(writer, sheet_name=i)
# writer.save()
# data_lar_0.head()

# %% [markdown]
# ### 대분류x제공자료컬럼
# 1. 널 삭제
# 2. 워딩 카운팅 및 정렬

# %%
#대분류x제공자료컬럼
#대분류x체크박스항목

# %%
# 체크박스항목1,2,3 리스트
chkBox_catgr_list_1 = data['체크박스항목1'].drop_duplicates().reset_index()
chkBox_catgr_list_2 = data['체크박스항목2'].drop_duplicates().reset_index()
chkBox_catgr_list_3 = data['체크박스항목3'].drop_duplicates().reset_index()

# 체크박스 카테고리 사전
chkBox_catgr_list_1.columns = ['index', '체크박스항목']
chkBox_catgr_list_2.columns = ['index', '체크박스항목']
chkBox_catgr_list_3.columns = ['index', '체크박스항목']
chkBox_catgr_list_total = pd.concat([chkBox_catgr_list_1,chkBox_catgr_list_2,chkBox_catgr_list_3], axis=0)
chkBox_catgr_list_total
# Out:
#     index           체크박스항목
# 0       0               지점
# 1      17              NaN
# 2      54            지점-농업
# 3     100           지점-강원도
# 4     280            지점-황사
# 5     320            지점-부이
# 6     348            지점-등표
# 7     364          지점-파고부이
# 8     447          지점-레윈존데
# 9     457       지점-윈드프로파일러
# 10    470            지점-항공
# 11    872               분류
# 12    916             자료형태
# 13   1035             자료구분
# 14   1301            지점-지점
# 15   1325             자료종류
# 16   1532        수치모델-자료구분
# 17   1609            시간-시간
# 18   1633        수치모델-해양모델
# 19   1643          지점-국지해안
# 20   1648          시간-분석시간
# 21   1672          지점-온실가스
# 22   1681          지점-반응가스
# 23   1687          지점-에어로졸
# 24   1739          지점-대기복사
# 25   1748         지점-성층권오존
# 26   1751               구분
# 27   1754           지점-자외선
# 28   1758         지점-총대기침적
# 29   1788               응용
# 30   1832               규모
# 31   1861               시간
# 32   1883               종류
# 33   2048               지역
# 34   2069          지점-관측분야
# 35   2091               관측
# 0       0               관측
# 1      12              NaN
# 2     447          관측-레윈존데
# 3     457  관측-윈드프로파일러(UHC)
# 4     704         관측-GTS고층
# 5    1035     자료형태-이진(bin)
# 6    1055         자료형태-HDF
# 7    1057          자료형태-영상
# 8    1119      자료형태-NetCDF
# 9    1187        자료형태-바이너리
# 10   1225         자료형태-이미지
# 11   1301               시간
# 12   1349            예보-요소
# 13   1408            예보-특보
# 14   1514           예보-영향도
# 15   1532          시간-분석시간
# 16   1648          시간-예측시간
# 17   1672          기후-온실가스
# 18   1681          기후-반응가스
# 19   1687               기후
# 20   1748         기후-성층권오존
# 21   1754           기후-자외선
# 22   1772        기후-표준강수지수
# 23   1788               지점
# 24   2039               분류
# 0       0              NaN
# 1     100               기관
# 2    1035            지역-영역
# 3    1225     기본산출물_이미지-지역
# 4    1532          시간-예측시간

# %%
# 체크박스항목1,2,3 리스트
chkBox_1 = data.loc[data['체크박스항목1'].notna(), '체크박스항목1'].reset_index()
chkBox_2 = data.loc[data['체크박스항목2'].notna(), '체크박스항목2'].reset_index()
chkBox_3 = data.loc[data['체크박스항목3'].notna(), '체크박스항목3'].reset_index()

# 체크박스 카테고리 사전
chkBox_1.columns = ['index', '체크박스항목']
chkBox_2.columns = ['index', '체크박스항목']
chkBox_3.columns = ['index', '체크박스항목']
chkBox_total = pd.concat([chkBox_1,chkBox_2,chkBox_3], axis=0).reset_index(drop=True)
chkBox_total
# Out:
#       index   체크박스항목
# 0         0       지점
# 1         1       지점
# 2         2       지점
# 3         3       지점
# 4         4       지점
# ...     ...      ...
# 2740   1604  시간-예측시간
# 2741   1605  시간-예측시간
# 2742   1606  시간-예측시간
# 2743   1607  시간-예측시간
# 2744   1608  시간-예측시간
#
# [2745 rows x 2 columns]

# %%
chkBox_total.columns
# Out:
# Index(['index', '체크박스항목'], dtype='object')

# %%
chkBox_total.loc[300,'체크박스항목']
# Out:
# '지점-파고부이'

# %%
chkBox_total.iloc[1608,1].split("-")[0]
# Out:
# '관측'

# %%
chkBox_total['체크박스항목'][0].str.split("-")
# Out:
# 0    [지점]
# 0    [관측]
# 0    [기관]
# Name: 체크박스항목, dtype: object

# %%
chkBox_total.loc[0,'체크박스항목'].split("-")[0]
# Out:
# '지점'

# %%
chkBox_total['체크박스항목이용'] = ''

# %%
chkBox_total.loc[0,'체크박스항목']
# Out:
# '지점'

# %%
chkBox_total.loc[0,'체크박스항목'].split("-")[0]
# Out:
# '지점'

# %%
range(len(chkBox_total))
# Out:
# range(0, 2745)

# %%
for i in range(len(chkBox_total)):
    chkBox_total.loc[i, '체크박스항목이용'] = chkBox_total.loc[i,'체크박스항목'].split("-")[0]
chkBox_total
# Out:
#       index   체크박스항목 체크박스항목이용
# 0         0       지점       지점
# 1         1       지점       지점
# 2         2       지점       지점
# 3         3       지점       지점
# 4         4       지점       지점
# ...     ...      ...      ...
# 2740   1604  시간-예측시간       시간
# 2741   1605  시간-예측시간       시간
# 2742   1606  시간-예측시간       시간
# 2743   1607  시간-예측시간       시간
# 2744   1608  시간-예측시간       시간
#
# [2745 rows x 3 columns]

# %%
chkBox_total['체크박스항목'].str.split("-")
# Out:
# 0            [지점]
# 1            [지점]
# 2            [지점]
# 3            [지점]
# 4            [지점]
#           ...
# 365    [시간, 예측시간]
# 366    [시간, 예측시간]
# 367    [시간, 예측시간]
# 368    [시간, 예측시간]
# 369    [시간, 예측시간]
# Name: 체크박스항목, Length: 2745, dtype: object

# %%
chkBox_total.groupby('체크박스항목').sum()
# Out:
#                   index
# 체크박스항목
# 관측                92005
# 관측-GTS고층           4239
# 관측-레윈존데            2697
# 관측-윈드프로파일러(UHC)    2757
# 구분                32661
# 규모                53534
# 기관                 3051
# 기본산출물_이미지-지역      95950
# 기후                22347
# 기후-반응가스            6730
# 기후-성층권오존           1748
# 기후-온실가스           11725
# 기후-자외선             3509
# 기후-표준강수지수         17765
# 분류               162115
# 수치모델-자료구분          4599
# 수치모델-해양모델         16375
# 시간                97265
# 시간-분석시간           31778
# 시간-시간             38892
# 시간-예측시간          160718
# 예보-영향도            12160
# 예보-요소             44016
# 예보-특보             16962
# 응용                21594
# 자료구분             319420
# 자료종류               9296
# 자료형태               1833
# 자료형태-HDF          36911
# 자료형태-NetCDF       77359
# 자료형태-바이너리          4754
# 자료형태-영상           74691
# 자료형태-이미지          95950
# 자료형태-이진(bin)      20890
# 종류               122528
# 지역                 6147
# 지역-영역            214605
# 지점               817371
# 지점-강원도            26928
# 지점-관측분야           16580
# 지점-국지해안            8225
# 지점-농업               649
# 지점-대기복사            3479
# 지점-등표              3525
# 지점-레윈존데            4515
# 지점-반응가스            5046
# 지점-부이              9338
# 지점-성층권오존           3497
# 지점-에어로졸            6754
# 지점-온실가스            5019
# 지점-윈드프로파일러         6019
# 지점-자외선             5265
# 지점-지점             40460
# 지점-총대기침적           3517
# 지점-파고부이           33615
# 지점-항공              3311
# 지점-황사             10081

# %%
#제공자료컬럼 널 삭제
# 한 엑셀 파일에 저장
writer=pd.ExcelWriter(output_path + "lar_catgr.xlsx", engine='openpyxl')

for i,j in zip(range(len(lar_catgr)), lar_catgr):
    globals()["data_lar_{}".format(i)] = globals()["data_lar_{}".format(i)][globals()["data_lar_{}".format(i)]['제공자료컬럼'].notna()]
    globals()["data_lar_groupBy_{}".format(i)]= globals()["data_lar_{}".format(i)].groupby(['제공자료컬럼']).sum().reset_index().sort_values('INDEX', ascending = False)
    globals()["noun_{}".format(i)] = globals()["data_lar_groupBy_{}".format(i)].iloc[:,0].to_list()
    globals()["cnt_{}".format(i)] = globals()["data_lar_groupBy_{}".format(i)].iloc[:,1].to_list()
    globals()["cloud_dict_{}".format(i)] = dict(zip(globals()["noun_{}".format(i)],globals()["cnt_{}".format(i)]))
    globals()["data_lar_groupBy_{}".format(i)].to_excel(writer, sheet_name=j)
writer.save()

# noun = data_lar_groupBy_3.iloc[:,0].to_list()
# cnt = data_lar_groupBy_3.iloc[:,1].to_list()
# cloud_dict = dict(zip(noun,cnt))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [70], in <cell line: 5>()
#       3 writer=pd.ExcelWriter(output_path + "lar_catgr.xlsx", engine='openpyxl')
#       5 for i,j in zip(range(len(lar_catgr)), lar_catgr):
# ----> 6     globals()["data_lar_{}".format(i)] = globals()["data_lar_{}".format(i)][globals()["data_lar_{}".format(i)]['제공자료컬럼'].notna()]
#       7     globals()["data_lar_groupBy_{}".format(i)]= globals()["data_lar_{}".format(i)].groupby(['제공자료컬럼']).sum().reset_index().sort_values('INDEX', ascending = False)
#       8     globals()["noun_{}".format(i)] = globals()["data_lar_groupBy_{}".format(i)].iloc[:,0].to_list()
#
# KeyError: 'data_lar_0'

# %%
# 워드 클라우드 사이즈 참고
okt = Okt()
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)

# %%
val = cloud_dict_0
gen = wc.generate_from_frequencies(val)
print(lar_catgr[0])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_0.head(5)

# %%
val = cloud_dict_1
gen = wc.generate_from_frequencies(val)
print(lar_catgr[1])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_1.head(5)

# %%
val = cloud_dict_2
gen = wc.generate_from_frequencies(val)
print(lar_catgr[2])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_2.head(5)

# %%
val = cloud_dict_3
gen = wc.generate_from_frequencies(val)
print(lar_catgr[3])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_3.head(5)

# %%
val = cloud_dict_4
gen = wc.generate_from_frequencies(val)
print(lar_catgr[4])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_4.head(5)

# %%
val = cloud_dict_5
gen = wc.generate_from_frequencies(val)
print(lar_catgr[5])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_5.head(5)

# %%
val = cloud_dict_6
gen = wc.generate_from_frequencies(val)
print(lar_catgr[6])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_6.head(5)

# %%
val = cloud_dict_7
gen = wc.generate_from_frequencies(val)
print(lar_catgr[7])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_7.head(5)

# %%
val = cloud_dict_8
gen = wc.generate_from_frequencies(val)
print(lar_catgr[8])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_8.head(5)

# %%
val = cloud_dict_9
gen = wc.generate_from_frequencies(val)
print(lar_catgr[9])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_9.head(5)

# %%
val = cloud_dict_10
gen = wc.generate_from_frequencies(val)
print(lar_catgr[10])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_10.head(5)

# %%
val = cloud_dict_11
gen = wc.generate_from_frequencies(val)
print(lar_catgr[11])
plt.figure()
plt.imshow(gen)
data_lar_groupBy_11.head(5)

# %%
data['대분류'].drop_duplicates().reset_index()['대분류']

# %%
data['중분류'].drop_duplicates().reset_index()

# %%
a = data['중분류'].drop_duplicates().reset_index()
aa = a['index'].to_list()
data.loc[aa,'대분류']

# %%
data.loc[aa,'대분류']

# %%
col_list = data.columns.to_list()

# %%
col = col_list[6]
print(col)
data[col].str.split('-').map(lambda x : x)

# %%
col = col_list[8]
print(col)
data[col].str.split('-').map(lambda x: x)

# %%
# 컬럼 추리기
col = col_list[6]
print(col)
tmp = data.loc[data[col].notna(), col].reset_index()
tmp = tmp['체크박스항목1']
# data[col].str.split('-').map(lambda x: x)
tmp

# %%
len(tmp)

# %%
tmp.head(100)

# %%
# '-' 포함한 단어들만 추리기
tmp_list = []
for i in range(len(tmp)):
    if re.findall('-', tmp[i]) == ['-']:
        tmp_list.append(i)

# %%
tmp[35].split('-')

# %%
tmp[tmp_list]

# %%
tmp[0]

# %%
tmp.isin('-')

# %%
tmp.str.split('-').map(lambda x: x[0])

# %%
os.getcwd()

# %% [markdown]
# # 워드 클라우드 ( 테스트)

# %%
import jpype

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image
import numpy as np

# %%
with open(input_path + 'test1.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc = WordCloud(font_path='malgun', width=10000, height=10000, scale=2.0, max_font_size=2500)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
# 엑셀 한 시트에 저장
# #1. 파일 생성
# writer=pd.ExcelWriter('테스트파일명.xlsx', engine='openpyxl')
 
# #2. 생성 파일에 시트명 지정 후 dataframe에 저장한 결과값 넣기
# df1.to_excel(writer, sheet_name='sheet1')
 
 
# # 3. 작성 완료 후 파일 저장
# writer.save()

# %%
# 워드 클라우드

from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image
import numpy as np

with open(input_path + 'test1.txt', 'r', encoding='utf-8') as f:
    text = f.read()
    
okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)
