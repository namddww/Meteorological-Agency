# %%
# 워드 클라우드
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image

import pandas as pd
import numpy as np
import os
import string
import sys
import re
import datetime as dt
# now = dt.datetime.now().strftime('%y%m%d_%H%M%S')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# 진행 여부 함수
def yes_or_no(question):
    while "the answer is invalid":
        reply = str(input(question+' (y/n): ')).lower().strip()
        if reply[0] == 'y':
            return True
        if reply[0] == 'n':
            return False
        else:
            print("실패: 'y' 혹은 'n' 를 입력해 주세요")

# %%
# 파일 불러오기
sheet_name = "컬럼분석"
input_path = os.path.join(os.getcwd(), "data\\")
output_path = os.path.join(os.getcwd(), "data\\out\\")
data = pd.read_excel(input_path+"기상자료개방포털 컬럼 조사.xlsx", sheet_name=sheet_name, header=0)

# # null 제거
# for i in range(len(input_test.columns)):
#     input_test[input_test.columns[i]] = input_test[input_test.columns[i]].fillna("")
# print(input_test.shape)
# input_test.head(5)

# %% [markdown]
# ### 분류 리스트(사전) 생성

# %%
# 대분류 리스트
lar_catgr = data['대분류'].drop_duplicates().reset_index()['대분류']
# 중분류 리스트
mid_catgr = data['중분류'].drop_duplicates().reset_index()['중분류']
# 소분류 리스트
sml_catgr = data['소분류'].drop_duplicates().reset_index()['소분류']
# 전체 분류 리스트(사전)
tmp = data['소분류'].drop_duplicates().reset_index()
tmp_list = tmp['index'].to_list()
total_catgr = data.loc[tmp_list,['대분류','중분류','소분류']]
total_catgr
# Out:
#            대분류          중분류                       소분류
# 0         기상관측           지상              종관기상관측(ASOS)
# 37        기상관측           지상               방재기상관측(AWS)
# 54        기상관측           지상              농업기상관측(AAOS)
# 83        기상관측           지상                    북한기상관측
# 100       기상관측           지상                 공공기관 기상관측
# 253       기상관측           지상                      계절관측
# 280       기상관측           지상                      황사관측
# 314       기상관측           지상                      낙뢰관측
# 320       기상관측           해양                    해양기상부이
# 348       기상관측           해양                    등표기상관측
# 364       기상관측           해양                      파고부이
# 447       기상관측           고층                      레윈존데
# 457       기상관측           고층                    연직바람관측
# 470       기상관측           항공              공항기상관측(AMOS)
# 495       기상관측  세계기상전문(GTS)                 지상(SYNOP)
# 641       기상관측  세계기상전문(GTS)                  부이(BUOY)
# 704       기상관측  세계기상전문(GTS)                  고층(TEMP)
# 872       기상관측  세계기상전문(GTS)                 태풍예보(TYP)
# 916       기상관측  세계기상전문(GTS)            위험기상정보(SIGMET)
# 932       기상관측  세계기상전문(GTS)                기후(CLIMAT)
# 1035      기상위성    천리안 위성 1호                 천리안 위성 1호
# 1119      기상위성   천리안 위성 2A호                천리안 위성 2A호
# 1301       레이더          사이트                       사이트
# 1325       레이더           합성                        합성
# 1349      기상예보         동네예보                     초단기실황
# 1367      기상예보         동네예보                     초단기예보
# 1385      기상예보         동네예보                      단기예보
# 1403      기상예보         동네예보                      중기예보
# 1408      기상예보         기상특보                      기상특보
# 1420      기상예보         태풍예보                      태풍목록
# 1428      기상예보         태풍예보                      태풍정보
# 1452      기상예보         태풍예보                  태풍정보(TD)
# 1477      기상예보         태풍예보                     태풍발생표
# 1491      기상예보         태풍예보                      태풍경로
# 1514      기상예보         영향예보                        폭염
# 1523      기상예보         영향예보                        한파
# 1532      수치모델        단중기예측             지역예보모델(RDAPS)
# 1561      수치모델        단중기예측             국지예보모델(LDAPS)
# 1609      수치모델        초단기예측  초단기예보모델(KLAPS)분석(KL05)자료
# 1633      수치모델         파랑모델                   전지구파랑모델
# 1638      수치모델         파랑모델                    지역파랑모델
# 1643      수치모델         파랑모델                  국지연안파랑모델
# 1648      수치모델         파랑모델                   해구별예측자료
# 1672        기후       기후변화감시                      온실가스
# 1681        기후       기후변화감시                      반응가스
# 1687        기후       기후변화감시                      에어로졸
# 1739        기후       기후변화감시                      대기복사
# 1748        기후       기후변화감시                 성층권오존오존전량
# 1751        기후       기후변화감시                 성층권오존연직분포
# 1754        기후       기후변화감시                       자외선
# 1758        기후       기후변화감시                     총대기침적
# 1772        기후           가뭄                    표준강수지수
# 1788      응용기상         기상지수                    생활기상지수
# 1806      응용기상         기상지수                    보건기상지수
# 1824      응용기상       기상지원지도                   태양광자원지도
# 1828      응용기상       기상지원지도                    풍령자원지도
# 1832      지진화산      지진화산특정보                      지진정보
# 1841      지진화산      지진화산특정보                      미소지진
# 1866  날씨이슈별데이터           황사                        황사
# 1876  날씨이슈별데이터           태풍                        태풍
# 1883      역사기후        자기기록지                     자기기록지
# 1927      역사기후        종이일기도                     종이일기도
# 1937      역사기후        통계원부류                     통계원부류
# 2034      역사기후         역사자료                  해관기상관측자료
# 2039      역사기후         역사자료                    조선왕조실록
# 2048      역사기후         역사자료                      각사등록
# 2053      역사기후        기상기록집                     기상기록집
# 2059     메타데이터         지점정보                    관측지점정보
# 2069     메타데이터         통계정보                    기후통계정보
# 2089      품질정보         품질현황                      품질현황
# 2091      품질정보     데이터품질리포트                  데이터품질리포트
# 2113      수치모델      수치분석일기도             분석일기도(지상, 고층)
# 2114      수치모델      수치분석일기도                 분석일기도(황사)
# 2115      수치모델      수치분석일기도           분석일기도(지상, 12시간)
# 2116      수치모델      수치분석일기도            분석일기도(지상, 3시간)
# 2117      수치모델      수치분석일기도           지역파랑모델 수치예상 일기도

# %% [markdown]
# # 함수 & 옵션 관리

# %%
# dict 변환 함수
def cnv_dict(input):
    noun = input.iloc[:,0].to_list()
    cnt = input.iloc[:,1].to_list()
    globals()["cloud_dict"] = dict(zip(noun,cnt))
    print('cnv_dict:success - cloud_dict')
    
# 워드 클라우드 사이즈
okt = Okt()
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)

# 워드클라우드 생성
def w_cloud(val, expln):
    gen = wc.generate_from_frequencies(val)
    plt.figure()
    plt.imshow(gen)
    print(expln.head())
    print(expln.shape)
    
# 데이터 복사하기
def data_copy(data):
    globals()["copied"] = data.copy()
    print("copied")

# %% [markdown]
# ### 모델 A (자료제공컬럼 - 전체/대분류별 통계)
# #### 1. 모델 A-1(자료제공컬럼 - 전체)

# %%
# 모델 A: 제공자료컬럼만 그룹바이
data_A = data.groupby(['대분류', '중분류', '소분류', '제공자료컬럼']).head()

# 제공자료컬럼 카운팅
data_A_1 = pd.DataFrame(data_A.groupby('제공자료컬럼')['INDEX'].count()).reset_index().sort_values('INDEX', ascending=False)
data_A_1.columns = ['제공자료컬럼', 'count']

print(data_A.shape)
data_A.head()
# Out:
# (679, 17)
#    INDEX   대분류 중분류           소분류    제공자료컬럼                   예시 체크박스항목1  \
# 0      1  기상관측  지상  종관기상관측(ASOS)        지점               속초(90)      지점
# 1      1  기상관측  지상  종관기상관측(ASOS)        시간  2022-11-01 01:00:00      지점
# 2      1  기상관측  지상  종관기상관측(ASOS)    기온(°C)                 10.4      지점
# 3      1  기상관측  지상  종관기상관측(ASOS)  기온 QC플래그                  NaN      지점
# 4      1  기상관측  지상  종관기상관측(ASOS)   강수량(mm)                  NaN      지점
#
#   체크박스항목예시1 체크박스항목1Depth 체크박스항목2 체크박스항목예시2 체크박스항목2Depth 체크박스항목3 체크박스항목예시3  \
# 0       강원도           +1      관측   지면.초상온도           +1     NaN       NaN
# 1       경기도           +1      관측      현상번호           +1     NaN       NaN
# 2      경상남도           +1      관측        기온           +1     NaN       NaN
# 3      경상북도           +1      관측        강수           +1     NaN       NaN
# 4     광주광역시           +1      관측        바람           +1     NaN       NaN
#
#   체크박스항목3Depth   추가 특이사항
# 0          NaN  NaN  NaN
# 1          NaN  NaN  NaN
# 2          NaN  NaN  NaN
# 3          NaN  NaN  NaN
# 4          NaN  NaN  NaN

# %%
# dict 변환
cnv_dict(data_A_1)
# Out:
# cnv_dict:success - cloud_dict

# %%
# 모델 A-1 분석 결과
print('===== 제공자료컬럼 - 전체 카운팅 =====')
w_cloud(cloud_dict, data_A_1)
# Out:
# ===== 제공자료컬럼 - 전체 카운팅 =====
#     제공자료컬럼  count
# 340     지점     24
# 155     번호     23
# 188     시간     22
# 104     구분     16
# 339     지역     10
# (446, 2)

# %%
# dict 복사
data_copy(cloud_dict)

# 제거 옵션
copied.pop('지점')
# copied.pop('번호')
# copied.pop('시간')
# copied.pop('구분')
# copied.pop('지역')
# copied.pop('날짜')
w_cloud(copied, data_A_1)
# Out:
# copied
#     제공자료컬럼  count
# 340     지점     24
# 155     번호     23
# 188     시간     22
# 104     구분     16
# 339     지역     10
# (446, 2)

# %% [markdown]
# #### 2. 모델 A-2(자료제공컬럼 - 대분류별 통계)

# %%
# 각 데이터셋 분류
# 한 엑셀 파일에 저장
writer=pd.ExcelWriter(output_path + "model_a_2.xlsx", engine='openpyxl')
for i,j in zip(lar_catgr,range(len(lar_catgr))):
    globals()["data_lar_A_{}".format(j)] = data_A['대분류'] == i
    globals()["data_lar_A_{}".format(j)] = data_A[globals()["data_lar_A_{}".format(j)]==True]
    globals()["data_lar_A_{}".format(j)].to_excel(writer, sheet_name=i)
writer.save()
print(data_lar_A_0.shape)
data_lar_A_0.head()
# Out:
# (319, 17)
#    INDEX   대분류 중분류           소분류    제공자료컬럼                   예시 체크박스항목1  \
# 0      1  기상관측  지상  종관기상관측(ASOS)        지점               속초(90)      지점
# 1      1  기상관측  지상  종관기상관측(ASOS)        시간  2022-11-01 01:00:00      지점
# 2      1  기상관측  지상  종관기상관측(ASOS)    기온(°C)                 10.4      지점
# 3      1  기상관측  지상  종관기상관측(ASOS)  기온 QC플래그                  NaN      지점
# 4      1  기상관측  지상  종관기상관측(ASOS)   강수량(mm)                  NaN      지점
#
#   체크박스항목예시1 체크박스항목1Depth 체크박스항목2 체크박스항목예시2 체크박스항목2Depth 체크박스항목3 체크박스항목예시3  \
# 0       강원도           +1      관측   지면.초상온도           +1     NaN       NaN
# 1       경기도           +1      관측      현상번호           +1     NaN       NaN
# 2      경상남도           +1      관측        기온           +1     NaN       NaN
# 3      경상북도           +1      관측        강수           +1     NaN       NaN
# 4     광주광역시           +1      관측        바람           +1     NaN       NaN
#
#   체크박스항목3Depth   추가 특이사항
# 0          NaN  NaN  NaN
# 1          NaN  NaN  NaN
# 2          NaN  NaN  NaN
# 3          NaN  NaN  NaN
# 4          NaN  NaN  NaN

# %%
# 카운트점검
for i,j in zip(range(len(lar_catgr)),lar_catgr):
    print(str(j) + ": " + str(globals()["data_lar_A_{}".format(i)].shape))
# Out:
# 기상관측: (319, 17)
# 기상위성: (11, 17)
# 레이더: (8, 17)
# 기상예보: (75, 17)
# 수치모델: (30, 17)
# 기후: (112, 17)
# 응용기상: (18, 17)
# 지진화산: (12, 17)
# 날씨이슈별데이터: (20, 17)
# 역사기후: (39, 17)
# 메타데이터: (12, 17)
# 품질정보: (23, 17)

# %%
data_A.groupby(['대분류', '중분류', '소분류', '제공자료컬럼']).head().shape
# Out:
# (679, 17)

# %%
pd.DataFrame(data_A.groupby('제공자료컬럼')['INDEX'].count()).reset_index().sort_values('INDEX', ascending=False)
# Out:
#                                 제공자료컬럼  INDEX
# 340                                 지점     24
# 155                                 번호     23
# 188                                 시간     22
# 104                                 구분     16
# 339                                 지역     10
# 122                                 날짜      9
# 426                            풍속(m/s)      8
# 387                          파일사이즈(GB)      8
# 299                               자료종류      7
# 431                            풍향(deg)      7
# 113                             기온(°C)      7
# 442                          현지기압(hPa)      6
# 437                          해면기압(hPa)      6
# 289                                 일시      5
# 256                             용량(KB)      4
# 92                                  경도      4
# 268                                 위도      4
# 281                          이슬점온도(°C)      4
# 272                            유의파고(m)      4
# 175                                생산일      4
# 187                              습도(%)      4
# 443                                 형식      4
# 173                               상세정보      3
# 84                             강수량(mm)      3
# 179                             수온(°C)      3
# 211                                영향도      3
# 277                                이미지      3
# 389                           파주기(sec)      3
# 358                            최대파고(m)      3
# 259                                  월      3
# 98                                관측시간      3
# 127                                  년      3
# 132                               다운로드      3
# 190                            시간(UTC)      3
# 106                                 규모      2
# 162                                 분야      2
# 323                               중심기압      2
# 385                               통계방법      2
# 324                          중심기압(hPa)      2
# 282                                  일      2
# 63                         70%확률반경(km)      2
# 326                         중심위치-경도(E)      2
# 327                         중심위치-위도(N)      2
# 380                                태풍명      2
# 298                           자료용량(MB)      2
# 375                                 크기      2
# 149                               발표시각      2
# 159                                 분류      2
# 338                                 지수      2
# 96                               고도(m)      2
# 342                               지점번호      2
# 345                             진앙(km)      2
# 111                                 기온      2
# 171                            상대습도(%)      2
# 346                               진행방향      2
# 87                      강풍반경(km)[예외반경]      2
# 361                       최대풍속-초속(m/s)      2
# 360                      최대풍속-시속(km/h)      2
# 81                                  강도      2
# 70                                 PDF      2
# 388                          파일사이즈(MB)      2
# 275                         이동속도(km/h)      2
# 249                               예보시간      2
# 250                            예보시간-내일      2
# 429                           풍향(16방위)      2
# 251                            예보시간-모레      2
# 252                            예보시간-오늘      2
# 422                                 풍속      2
# 419                            평균파고(m)      2
# 390                            파향(deg)      2
# 270                                 위치      2
# 202                                 연도      2
# 320                               종료시각      2
# 193                            시정(10m)      2
# 192                               시작시각      2
# 276                              이론자료수      1
# 311                  정시 누적 전천복사(MJ/m2)      1
# 306                          전운량(10분위)      1
# 254            온도-평균 크기별 부피농도(0.5~20㎛)      1
# 253                              오류자료수      1
# 283                     일 누적 일사(MJ/m2)      1
# 279                             이슬점 온도      1
# 307                             전운량(할)      1
# 280                              이슬점온도      1
# 308                              정상자료수      1
# 309                  정시 누적 반사복사(MJ/m2)      1
# 248                               예보시각      1
# 310                   정시 누적 순복사(MJ/m2)      1
# 247                     예보96H 폭풍반경(km)      1
# 312                       정시 조도(10lux)      1
# 255                                 요소      1
# 246                      예보96H 초속(m/s)      1
# 313                        정시 지면온도(°C)      1
# 245                         예보96H 중심기압      1
# 314                        정시 지하수위(cm)      1
# 315                        정시 초상온도(°C)      1
# 316                             정역학일치성      1
# 317                                 제목      1
# 244                        예보96H 위도(N)      1
# 318                                 제비      1
# 243                     예보96H 시속(km/h)      1
# 242                        예보96H 경도(E)      1
# 319                                종달새      1
# 241                     예보96H 강풍반경(km)      1
# 240                     예보72H 폭풍반경(km)      1
# 305                           전운량(1/8)      1
# 278                              이미지파일      1
# 288                          일사(MJ/m2)      1
# 296                               입력시각      1
# 287                           일사 QC플래그      1
# 274                            이동방향 속도      1
# 290                           일조 QC플래그      1
# 291                             일조(hr)      1
# 292                          일최고기온(°C)      1
# 273                               은행나무      1
# 286                   일누적 자외선 A(MJ/m2)      1
# 293                   일최대 자외선 B(W/m2 )      1
# 271                             유명산 단풍      1
# 321                                 종류      1
# 294                          일최저기온(°C)      1
# 269                              위도(N)      1
# 267                           월평균 현지기압      1
# 295                      일평균 기온의 월표준편차      1
# 266                           월평균 해면기압      1
# 304                       전기전도도(μS/cm)      1
# 265                          월평균 일최저기온      1
# 264                          월평균 일최고기온      1
# 297                               자료구분      1
# 263                             월평균 기온      1
# 262                          월중 최대풍속 날      1
# 261                            월중 최대풍속      1
# 260                              월일조시간      1
# 258                           운형(운형약어)      1
# 300                               자료형태      1
# 285                               일기현상      1
# 302                                 저자      1
# 284                        일 누적 일조(hr)      1
# 303                             적설(cm)      1
# 257                               우박일수      1
# 301                                잠자리      1
# 0                           0.1M 단위 파고      1
# 322                                주소지      1
# 386                             통계지침년도      1
# 412           평균 응결핵 수농도(0.01∼3㎛)(개/㎤)      1
# 411           평균 육불화황(SF₆) 배경대기농도(ppm)      1
# 410                        평균 오존전량(DU)      1
# 409     평균 염화불화탄소12(CFC12) 배경대기농도(ppm)      1
# 408   평균 염화불화탄소113(CFC113) 배경대기농도(ppm)      1
# 407     평균 염화불화탄소11(CFC11) 배경대기농도(ppm)      1
# 406          평균 아산화질소(N₂O) 배경대기농도(ppm)      1
# 405  평균 미세입자 크기별 수농도(0.008∼1.2 ㎛)(개/㎤)      1
# 404             평균 메탄(CH₄) 배경대기농도(ppm)      1
# 403                  평균 TSC700 nm(M/m)      1
# 402                  평균 TSC550 nm(M/m)      1
# 401                  평균 TSC450 nm(M/m)      1
# 400                  평균 BSC700 nm(M/m)      1
# 399                  평균 BSC550 nm(M/m)      1
# 398                  평균 BSC450 nm(M/m)      1
# 397                   평균 AC950 nm(M/m)      1
# 396                   평균 AC880 nm(M/m)      1
# 395                   평균 AC660 nm(M/m)      1
# 394                   평균 AC590 nm(M/m)      1
# 393                   평균 AC520 nm(M/m)      1
# 392                   평균 AC470 nm(M/m)      1
# 413          평균 이산화탄소(CO₂) 배경대기농도(ppm)      1
# 414               평균 이산화황(SO₂) 농도(ppb)      1
# 415               평균 일산화탄소(CO) 농도(ppb)      1
# 432                               하층운형      1
# 444                          황(S)(㎍/㎥)      1
# 441                         현지기압 QC플래그      1
# 440                               현지기압      1
# 439                          현상번호(국내식)      1
# 438                               해수욕장      1
# 436                         해면기압 QC플래그      1
# 435                               해면기압      1
# 434                               해구번호      1
# 433                         합계 강수량(mm)      1
# 430                           풍향(36방위)      1
# 416                평균 지표오존(O₃) 농도(ppb)      1
# 428                           풍향 QC플래그      1
# 427                                 풍향      1
# 425                           풍속(knot)      1
# 424                             풍속(KT)      1
# 423                           풍속 QC플래그      1
# 421                     표준등압면/유의고도 일치성      1
# 420                           폭풍반경(km)      1
# 418         평균 크기별 부피농도(0.5~20㎛)(μ㎥/㎤)      1
# 417              평균 질소산화물(NOｘ) 농도(ppb)      1
# 391                   평균 AC370 nm(M/m)      1
# 384                               통계기간      1
# 325                               중심위치      1
# 383                            태풍주의보센터      1
# 353                              최고 기온      1
# 352                            초속(m/s)      1
# 351                         철(Fe)(㎍/㎥)      1
# 350                    질산이온(NO₃⁻)(㎍/㎥)      1
# 349                  질산이온(NO₃⁻)(μeq/L)      1
# 348                          질량농도(㎍/㎥)      1
# 347                               진행여부      1
# 344                                진달래      1
# 343                         직달일사(W/m2)      1
# 341                                지점명      1
# 238                         예보72H 중심기압      1
# 337                                지속성      1
# 336                           지면온도(°C)      1
# 335                         지면온도 QC플래그      1
# 334                       지면상태(지면상태코드)      1
# 333                       지구하향복사(W/m2)      1
# 332                       지구상향복사(W/m2)      1
# 331                           증기압(hPa)      1
# 330                           중하층운량(할)      1
# 329                        중하층운량(10분위)      1
# 328                               중층운형      1
# 354                            최대 일강수량      1
# 355                        최대순간풍속(m/s)      1
# 356                        최대순간풍향(deg)      1
# 371                        칼슘(Ca)(㎍/㎥)      1
# 382                               태풍이름      1
# 381                               태풍번호      1
# 379                       태양하향복사(W/m2)      1
# 378                       태양상향복사(W/m2)      1
# 377                      타이타늄(Ti)(㎍/㎥)      1
# 376                        크롬(Cr)(㎍/㎥)      1
# 374                               코스모스      1
# 373                       코발트(Co)(㎍/㎥)      1
# 372                  칼슘이온(Ca²⁺)(μeq/L)      1
# 370                      칼륨이온(K⁺)(㎍/㎥)      1
# 357                             최대지상풍속      1
# 369                    칼륨이온(K⁺)(μeq/L)      1
# 368                         칼륨(K)(㎍/㎥)      1
# 367                       카드뮴(Cd)(㎍/㎥)      1
# 366                                측정일      1
# 365                            최저운고(할)      1
# 364                        최저운고(100m )      1
# 363                              최저 기온      1
# 362                              최소자릿수      1
# 359                         최대파주기(sec)      1
# 239                      예보72H 초속(m/s)      1
# 223                        예보24H 위도(N)      1
# 237                        예보72H 위도(N)      1
# 66                                  9월      1
# 77                                SPI4      1
# 76                                SPI3      1
# 75                               SPI24      1
# 74                                SPI2      1
# 73                               SPI18      1
# 72                               SPI12      1
# 71                                SPI1      1
# 69                         GUST풍속(m/s)      1
# 68                           COMIS_MQC      1
# 67                            CDMS_MQC      1
# 65                                  8월      1
# 79                                SPI6      1
# 64                                  7월      1
# 62                                  6월      1
# 61                        6시간후 최대풍속 예보      1
# 60                        6시간후 중심위치 예보      1
# 59                                  5월      1
# 58                        5cm 지중온도(°C)      1
# 57                     5CM 정시 지중온도(°C)      1
# 56                     50CM 정시 토양수분(%)      1
# 55                    5.0M 정시 지중온도(°C)      1
# 54                               4층 운형      1
# 78                                SPI5      1
# 80                                SPI9      1
# 52                           4층 운고(FT)      1
# 99                           관측시간(UTC)      1
# 112                           기온 QC플래그      1
# 110            기압-평균 크기별 부피농도(0.5~20㎛)      1
# 109                            기압(hPa)      1
# 108                                 기압      1
# 107                                기러기      1
# 105                               군락단지      1
# 103                        구리(Cu)(㎍/㎥)      1
# 102                            관측주기(분)      1
# 101                                관측일      1
# 100                               관측요소      1
# 97                                  관설      1
# 82                                 강수량      1
# 95                             고도(gpm)      1
# 94                                  고도      1
# 93                               경도(E)      1
# 91                               결측자료수      1
# 90                                 개나리      1
# 89                                 개구리      1
# 88                                 강하천      1
# 86                            강풍반경(km)      1
# 85                             강수확률(%)      1
# 83                           강수량 QC플래그      1
# 53                          4층 운량(1/8)      1
# 51                                  4월      1
# 115                               기후범위      1
# 13                    10CM 정시 지중온도(°C)      1
# 23                       18시간후 중심위치 예보      1
# 22                            16 방위 풍향      1
# 21                                 12월      1
# 20                       12시간후 최대풍속 예보      1
# 19                       12시간후 중심위치 예보      1
# 18                         12시간강수량(mm)      1
# 17                                 11월      1
# 16                                 10월      1
# 15                       10cm 지중온도(°C)      1
# 14                     10CM 정시 토양수분(%)      1
# 12                     1.5M 정시 풍속(m/s)      1
# 25                   1시간평균 미세먼지농도(㎍/㎥)      1
# 11                    1.5M 정시 지중온도(°C)      1
# 10                       1.5M 정시 습도(%)      1
# 9                       1.5M 정시 기온(°C)      1
# 8                     1.0M 정시 지중온도(°C)      1
# 7                          01.초 단위 파주기      1
# 6                   0.5mm 일 누적 강수량(mm)      1
# 5                     0.5M 정시 지중온도(°C)      1
# 4                        0.5M 정시 습도(%)      1
# 3                       0.5M 정시 기온(°C)      1
# 2                           0.5M 단위 파고      1
# 24                       18시간후 최대풍속 예보      1
# 26                                  1월      1
# 50                     4.0M 정시 풍속(m/s)      1
# 39                               2층 운형      1
# 49                      4.0M 정시 기온(°C)      1
# 48                               3층 운형      1
# 47                          3층 운량(1/8)      1
# 46                           3층 운고(FT)      1
# 45                                  3월      1
# 44                          3시간신적설(cm)      1
# 43                       30cm 지중온도(°C)      1
# 42                     30CM 정시 토양수분(%)      1
# 41                    30CM 정시 지중온도(°C)      1
# 40                    3.0M 정시 지중온도(°C)      1
# 38                          2층 운량(1/8)      1
# 27                           1초 단위 파주기      1
# 37                           2층 운고(FT)      1
# 36                                  2월      1
# 35                       24시간후 최대풍속 예보      1
# 34                       24시간후 중심위치 예보      1
# 33                       20cm 지중온도(°C)      1
# 32                     20CM 정시 토양수분(%)      1
# 31                    20CM 정시 지중온도(°C)      1
# 30                               1층 운형      1
# 29                          1층 운량(1/8)      1
# 28                           1층 운고(FT)      1
# 114                              기온(℃)      1
# 116                                 나비      1
# 236                     예보72H 시속(km/h)      1
# 197                      알루미늄(Al)(㎍/㎥)      1
# 208                     염소이온(Cl⁻)(㎍/㎥)      1
# 207                   염소이온(Cl⁻)(μeq/L)      1
# 206                                연합계      1
# 205                              연직일관성      1
# 204                             연직바람쉬어      1
# 203                       연직 바람성분(m/s)      1
# 201                                  연      1
# 200                                 얼음      1
# 199                  암모니아이온(NH₄⁺)(㎍/㎥)      1
# 198                암모니아이온(NH₄⁺)(μeq/L)      1
# 196                        아연(Zn)(㎍/㎥)      1
# 210                                 영역      1
# 195                              아까시나무      1
# 194                              시정(m)      1
# 191                           시속(km/h)      1
# 189                            시간(KST)      1
# 186                           습도 QC플래그      1
# 185                                 습도      1
# 184                      스트론튬(Sr)(㎍/㎥)      1
# 183                          순복사(W/m2)      1
# 182                           순간풍속(KT)      1
# 181                              수집자료수      1
# 209                                영문명      1
# 212                                 예보      1
# 178                                 소멸      1
# 225                      예보24H 초속(m/s)      1
# 235                        예보72H 경도(E)      1
# 234                     예보72H 강풍반경(km)      1
# 233                     예보48H 폭풍반경(km)      1
# 232                      예보48H 초속(m/s)      1
# 231                         예보48H 중심기압      1
# 230                        예보48H 위도(N)      1
# 229                     예보48H 시속(km/h)      1
# 228                        예보48H 경도(E)      1
# 227                     예보48H 강풍반경(km)      1
# 226                     예보24H 폭풍반경(km)      1
# 224                         예보24H 중심기압      1
# 213                    예보120H 강풍반경(km)      1
# 1                   0.1mm 일 누적 강수량(mm)      1
# 222                     예보24H 시속(km/h)      1
# 221                        예보24H 경도(E)      1
# 220                     예보24H 강풍반경(km)      1
# 219                    예보120H 폭풍반경(km)      1
# 218                     예보120H 초속(m/s)      1
# 217                        예보120H 중심기압      1
# 216                       예보120H 위도(N)      1
# 215                    예보120H 시속(km/h)      1
# 214                       예보120H 경도(E)      1
# 180                              수위(m)      1
# 177                                 서리      1
# 117                       나트륨(Na)(㎍/㎥)      1
# 131                        니켈(Ni)(㎍/㎥)      1
# 142                                 매미      1
# 141                        망간(Mn)(㎍/㎥)      1
# 140                  마그네슘이온(Mg²⁺)(㎍/㎥)      1
# 139                마그네슘이온(Mg²⁺)(μeq/L)      1
# 138                      마그네슘(Mg)(㎍/㎥)      1
# 137                       동서 바람성분(m/s)      1
# 136                                도서명      1
# 135                               단풍나무      1
# 134                                 단위      1
# 133                                 단계      1
# 130                                  눈      1
# 144                     몰리브데넘(Mo)(㎍/㎥)      1
# 129                               뇌우일수      1
# 128                                 년도      1
# 126                              내적일치성      1
# 125                                 내용      1
# 124                         납(Pb)(㎍/㎥)      1
# 123                       남북 바람성분(m/s)      1
# 121                              낙뢰 종류      1
# 120                              낙뢰 강도      1
# 119                    나트륨이온(Na⁺)(㎍/㎥)      1
# 118                  나트륨이온(Na⁺)(μeq/L)      1
# 143                                 매화      1
# 145                               물리한계      1
# 176                                서기력      1
# 161                          분석일시(UTC)      1
# 174                               상층운형      1
# 172                               상세보기      1
# 170                            산성도(pH)      1
# 169                         산란일사(W/m2)      1
# 168                                뻐꾸기      1
# 167            비해염황산이온(nss-SO₄²⁻)(㎍/㎥)      1
# 166             비해염칼슘이온(nss-Ca²⁺)(㎍/㎥)      1
# 165                                 비고      1
# 164                      불산이온(F⁻)(㎍/㎥)      1
# 163                    불산이온(F⁻)(μeq/L)      1
# 160                            분류 및 내용      1
# 146                        바나듐(V)(㎍/㎥)      1
# 158                                복숭아      1
# 157                             변화량 기압      1
# 156                                벚나무      1
# 154                                  뱀      1
# 153                                배나무      1
# 152                                발행처      1
# 151                               발행연도      1
# 150                          발표시간(UTC)      1
# 148                                 발생      1
# 147                        바륨(Ba)(㎍/㎥)      1
# 445                  황산이온(SO₄⁻)(μeq/L)      1

# %%
#제공자료컬럼 널 삭제
# 한 엑셀 파일에 저장
writer=pd.ExcelWriter(output_path + "data_lar_A_2ttttt.xlsx", engine='openpyxl')

for i,j in zip(range(len(lar_catgr)), lar_catgr):
    # 대분류마다 변수 지정
    globals()["data_A_{}".format(i)] = data_A.loc[data_A['대분류'] == j]
    
    # 분류된 데이터마다 그룹바이
    globals()["data_lar_A_{}".format(i)] = pd.DataFrame(
        globals()["data_A_{}".format(i)].groupby(
            '제공자료컬럼')['INDEX'].count()).reset_index().sort_values('INDEX', ascending=False)
    
    # 컬럼 정리
    globals()["data_lar_A_{}".format(i)].columns = ['제공자료컬럼', 'count']
    globals()["data_lar_A_{}".format(i)].to_excel(writer, sheet_name=j)

   
    
writer.save()

# %%
cnv_dict(data_lar_A_0)
print("===== 제공자료컬럼 - " + lar_catgr[0] + " =====")
w_cloud(cloud_dict, data_lar_A_0)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 기상관측 =====
#         제공자료컬럼  count
# 204         지점     15
# 104         시간     11
# 228    풍속(m/s)      7
# 75      기온(°C)      7
# 237  해면기압(hPa)      6
# (243, 2)

# %%
cnv_dict(data_lar_A_1)
print("===== 제공자료컬럼 - " + lar_catgr[1] + " =====")
w_cloud(cloud_dict, data_lar_A_1)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 기상위성 =====
#       제공자료컬럼  count
# 9  파일사이즈(GB)      2
# 0       관측시간      1
# 1  관측시간(UTC)      1
# 2        관측일      1
# 3         구분      1
# (10, 2)

# %%
cnv_dict(data_lar_A_2)
print("===== 제공자료컬럼 - " + lar_catgr[2] + " =====")
w_cloud(cloud_dict, data_lar_A_2)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 레이더 =====
#       제공자료컬럼  count
# 0       관측시간      2
# 1         구분      2
# 2         번호      2
# 3  파일사이즈(MB)      2
# (4, 2)

# %%
cnv_dict(data_lar_A_3)
print("===== 제공자료컬럼 - " + lar_catgr[3] + " =====")
w_cloud(cloud_dict, data_lar_A_3)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 기상예보 =====
#    제공자료컬럼  count
# 34     일시      4
# 39     지역      4
# 17     날짜      3
# 16     구분      3
# 28    영향도      3
# (47, 2)

# %%
cnv_dict(data_lar_A_4)
print("===== 제공자료컬럼 - " + lar_catgr[4] + " =====")
w_cloud(cloud_dict, data_lar_A_4)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 수치모델 =====
#       제공자료컬럼  count
# 0         구분      6
# 1         날짜      6
# 2         번호      6
# 5  파일사이즈(GB)      6
# 3    유의파고(m)      1
# (10, 2)

# %%
cnv_dict(data_lar_A_5)
print("===== 제공자료컬럼 - " + lar_catgr[5] + " =====")
w_cloud(cloud_dict, data_lar_A_5)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 기후 =====
#    제공자료컬럼  count
# 46     지점      9
# 32     시간      9
# 43   종료시각      2
# 33   시작시각      2
# 0    SPI1      1
# (94, 2)

# %%
cnv_dict(data_lar_A_6)
print("===== 제공자료컬럼 - " + lar_catgr[6] + " =====")
w_cloud(cloud_dict, data_lar_A_6)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 응용기상 =====
#     제공자료컬럼  count
# 2     다운로드      2
# 3       번호      2
# 4  예보시간-내일      2
# 5  예보시간-모레      2
# 6  예보시간-오늘      2
# (10, 2)

# %%
cnv_dict(data_lar_A_7)
print("===== 제공자료컬럼 - " + lar_catgr[7] + " =====")
w_cloud(cloud_dict, data_lar_A_7)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 지진화산 =====
#   제공자료컬럼  count
# 0     경도      2
# 1     규모      2
# 2     시간      2
# 3     위도      2
# 4     위치      2
# (6, 2)

# %%
cnv_dict(data_lar_A_8)
print("===== 제공자료컬럼 - " + lar_catgr[8] + " =====")
w_cloud(cloud_dict, data_lar_A_8)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 날씨이슈별데이터 =====
#    제공자료컬럼  count
# 0      구분      4
# 1      번호      4
# 2     생산일      4
# 3  용량(KB)      4
# 4      형식      4
# (5, 2)

# %%
cnv_dict(data_lar_A_9)
print("===== 제공자료컬럼 - " + lar_catgr[9] + " =====")
w_cloud(cloud_dict, data_lar_A_9)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 역사기후 =====
#    제공자료컬럼  count
# 18     지역      6
# 6      번호      5
# 16   자료종류      4
# 0     PDF      2
# 12     연도      2
# (20, 2)

# %%
cnv_dict(data_lar_A_10)
print("===== 제공자료컬럼 - " + lar_catgr[10] + " =====")
w_cloud(cloud_dict, data_lar_A_10)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 메타데이터 =====
#   제공자료컬럼  count
# 9   통계방법      2
# 0     경도      1
# 1   관측요소      1
# 2     단위      1
# 3     위도      1
# (11, 2)

# %%
cnv_dict(data_lar_A_11)
print("===== 제공자료컬럼 - " + lar_catgr[11] + " =====")
w_cloud(cloud_dict, data_lar_A_11)
# Out:
# cnv_dict:success - cloud_dict
# ===== 제공자료컬럼 - 품질정보 =====
#       제공자료컬럼  count
# 0   CDMS_MQC      1
# 12     연직일관성      1
# 21      지점번호      1
# 20       지속성      1
# 19    정역학일치성      1
# (23, 2)

# %%
data['대분류'].drop_duplicates().reset_index()['대분류']

# %%
data['중분류'].drop_duplicates().reset_index()

# %%
a = data['중분류'].drop_duplicates().reset_index()
aa = a['index'].to_list()
data.loc[aa,'대분류']

# %%
data.loc[aa,'대분류']

# %%
col_list = data.columns.to_list()

# %%
col = col_list[6]
print(col)
data[col].str.split('-').map(lambda x : x)

# %%
col = col_list[8]
print(col)
data[col].str.split('-').map(lambda x: x)

# %%
# 컬럼 추리기
col = col_list[6]
print(col)
tmp = data.loc[data[col].notna(), col].reset_index()
tmp = tmp['체크박스항목1']
# data[col].str.split('-').map(lambda x: x)
tmp

# %%
len(tmp)

# %%
tmp.head(100)

# %%
# '-' 포함한 단어들만 추리기
tmp_list = []
for i in range(len(tmp)):
    if re.findall('-', tmp[i]) == ['-']:
        tmp_list.append(i)

# %%
tmp[35].split('-')

# %%
tmp[tmp_list]

# %%
tmp[0]

# %%
tmp.isin('-')

# %%
tmp.str.split('-').map(lambda x: x[0])

# %%
os.getcwd()

# %% [markdown]
# # 워드 클라우드 ( 테스트)

# %%
import jpype

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image
import numpy as np

# %%
with open(input_path + 'test1.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
wc = WordCloud(font_path='malgun', width=10000, height=10000, scale=2.0, max_font_size=2500)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
# 엑셀 한 시트에 저장
# #1. 파일 생성
# writer=pd.ExcelWriter('테스트파일명.xlsx', engine='openpyxl')
 
# #2. 생성 파일에 시트명 지정 후 dataframe에 저장한 결과값 넣기
# df1.to_excel(writer, sheet_name='sheet1')
 
 
# # 3. 작성 완료 후 파일 저장
# writer.save()

# %%
# 워드 클라우드

from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import jpype
from konlpy.tag import Okt # <- jpype 부터 불러와야 불러오기 가능
from PIL import Image
import numpy as np

with open(input_path + 'test1.txt', 'r', encoding='utf-8') as f:
    text = f.read()
    
okt = Okt()
nouns = okt.nouns(text) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)
